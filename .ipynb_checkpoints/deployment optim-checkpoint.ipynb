# %%
import sys 
import os
sys.path.append(os.path.abspath("/Users/mouginot/work/helpmetric"))
import cymetrichelper as cyh
import pandahelper as pdh


import cymetric as cym
import pandas as pd

import matplotlib.pyplot as plt
from cymetric import graphs as cgr
from cymetric import timeseries as tm

# %matplotlib inline
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
cyh.MakeFlowGraph("main.sqlite")

# %%
db = cym.dbopen("main.sqlite")
ev = cym.Evaluator(db=db, write=False)

# %%
rec = ()

send = ['sfr_a','sfr_b']
nucs = ()
coms = ()


df1 = tm.transactions(ev, receivers=rec, senders=send, nucs=nucs, commodities=coms)

# %%
def month2year(df, mode=0, division=12):
    dfn = pd.DataFrame(columns=['Time','Mass'])
    df.rename(index=str, columns={"Quantity": "Mass"})
    val = 0
    for index, row in df.iterrows():
        if mode == 0:
            val = row['Mass']
        else:
            val += row['Mass']
        if row['Time'] % division == 0:
            if mode == 2:
                val *= 1./float(division)
            dfn.loc[int(row['Time'] / division)] = int(row['Time'] / 12)
            dfn.loc[int(row['Time'] / division)]['Mass'] = val
            val = 0
    return dfn
            
    
    
def maxperdiv(df, division=12):
    dfn = pd.DataFrame(columns=['Time','Mass'])
    val = 0
    for index, row in df.iterrows():
        if val < row['Mass']:
            val = row['Mass']
        if row['Time'] % division == 0:
            dfn.loc[int(row['Time'] / division)] = int(row['Time'] / 12)
            dfn.loc[int(row['Time'] / division)]['Mass'] = val
            val = 0
    return dfn

def increaseonly(df):
    dfn = pd.DataFrame(columns=['Time','Mass'])
    val = 0
    for index, row in df.iterrows():
        if val < row['Mass']:
            val = row['Mass']
            dfn.loc[int(row['Time'])] = int(row['Time'])
            dfn.loc[int(row['Time'])]['Mass'] = row['Mass']
            val = row['Mass']
    return dfn

# %%
df1_y = increaseonly(maxperdiv(df1,12))
df1_y['Mass'] = df1_y['Mass']/20000.

ax = df1_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
import numpy as np
major_y_ticks = np.arange(0, 25, 1)

ax.set_yticks(major_y_ticks)
major_x_ticks = np.arange(0, 200, 5)
ax.set_xticks(major_x_ticks)



# And a corresponding grid
ax.grid(which='both')

plt.show()

# %%
df1_y_unit = pd.DataFrame()

df1_y_unit['Time'] = df1_y['Time']
df1_y_build_unit = pd.DataFrame()
df1_y_unit['Unit'] = df1_y['Mass']


df1_y_unit['Unit'] = df1_y_unit['Unit'].apply(lambda x: int(x) + 1 if x > int(x) else int(x))


df1_y_build_unit['Time'] = df1_y_unit['Time']
df1_y_build_unit['Build'] = (df1_y_unit['Unit'] - df1_y_unit['Unit'].shift(1))
df1_y_build_unit= df1_y_build_unit.dropna()

#df1_y_build_unit['Build'] = df1_y_build_unit['Build'].apply(lambda x: int(x) + 1 if x > int(x) else int(x))
df1_y_build_unit = df1_y_build_unit.loc[df1_y_build_unit.Build>0]
df1_y_build_unit['Time'] *= 12.
print(df1_y_build_unit['Time'].values-12.)
print(df1_y_build_unit['Build'].values)

#### REMEMBER to add the first step !!
# Out:
# [1296.0 1884.0 1980.0 2016.0 2136.0 2172.0 2208.0]
# [2. 1. 1. 1. 1. 2. 2.]

# %%
df1_y_build_unit['Build'].sum()
# Out:
# 10.0

# %%
dfp = tm.get_power(ev)
# Out:
# /Users/mouginot/.local/lib/python3.5/site-packages/cymetric/timeseries.py:226: UserWarning: no faciity provided
#   warnings.warn(wng_msg, UserWarning)

# %%
dfp.plot('Time','Value',figsize = (20,12))

# %%
rec = ['fab_sfr']
send = ['str_pu']
nucs = ()
coms = ()


df2 = tm.transactions(ev, receivers=rec, senders=send, nucs=nucs, commodities=coms)

# %%
df2
# Out:
#       Time          Mass
# 0        0      0.000000
# 1        1      0.000000
# 2        2      0.000000
# 3        3      0.000000
# 4        4      0.000000
# 5        5      0.000000
# 6        6      0.000000
# 7        7      0.000000
# 8        8      0.000000
# 9        9      0.000000
# 10      10      0.000000
# 11      11      0.000000
# 12      12      0.000000
# 13      13      0.000000
# 14      14      0.000000
# 15      15      0.000000
# 16      16      0.000000
# 17      17      0.000000
# 18      18      0.000000
# 19      19      0.000000
# 20      20      0.000000
# 21      21      0.000000
# 22      22      0.000000
# 23      23      0.000000
# 24      24      0.000000
# 25      25      0.000000
# 26      26      0.000000
# 27      27      0.000000
# 28      28      0.000000
# 29      29      0.000000
# ...    ...           ...
# 2270  2270   2701.406280
# 2271  2271      0.000000
# 2272  2272      0.000000
# 2273  2273      0.000000
# 2274  2274      0.000000
# 2275  2275      0.000000
# 2276  2276   5402.743556
# 2277  2277      0.000000
# 2278  2278      0.000000
# 2279  2279      0.000000
# 2280  2280      0.000000
# 2281  2281   5937.554619
# 2282  2282  14407.521679
# 2283  2283      0.000000
# 2284  2284      0.000000
# 2285  2285      0.000000
# 2286  2286      0.000000
# 2287  2287      0.000000
# 2288  2288   5402.552750
# 2289  2289      0.000000
# 2290  2290      0.000000
# 2291  2291      0.000000
# 2292  2292      0.000000
# 2293  2293   2964.608940
# 2294  2294   5402.598942
# 2295  2295      0.000000
# 2296  2296      0.000000
# 2297  2297      0.000000
# 2298  2298      0.000000
# 2299  2299      0.000000
#
# [2300 rows x 2 columns]

# %%
df2
# Out:
#       Time          Mass
# 0        0      0.000000
# 1        1      0.000000
# 2        2      0.000000
# 3        3      0.000000
# 4        4      0.000000
# 5        5      0.000000
# 6        6      0.000000
# 7        7      0.000000
# 8        8      0.000000
# 9        9      0.000000
# 10      10      0.000000
# 11      11      0.000000
# 12      12      0.000000
# 13      13      0.000000
# 14      14      0.000000
# 15      15      0.000000
# 16      16      0.000000
# 17      17      0.000000
# 18      18      0.000000
# 19      19      0.000000
# 20      20      0.000000
# 21      21      0.000000
# 22      22      0.000000
# 23      23      0.000000
# 24      24      0.000000
# 25      25      0.000000
# 26      26      0.000000
# 27      27      0.000000
# 28      28      0.000000
# 29      29      0.000000
# ...    ...           ...
# 2270  2270   2701.406280
# 2271  2271      0.000000
# 2272  2272      0.000000
# 2273  2273      0.000000
# 2274  2274      0.000000
# 2275  2275      0.000000
# 2276  2276   5402.743556
# 2277  2277      0.000000
# 2278  2278      0.000000
# 2279  2279      0.000000
# 2280  2280      0.000000
# 2281  2281   5937.554619
# 2282  2282  14407.521679
# 2283  2283      0.000000
# 2284  2284      0.000000
# 2285  2285      0.000000
# 2286  2286      0.000000
# 2287  2287      0.000000
# 2288  2288   5402.552750
# 2289  2289      0.000000
# 2290  2290      0.000000
# 2291  2291      0.000000
# 2292  2292      0.000000
# 2293  2293   2964.608940
# 2294  2294   5402.598942
# 2295  2295      0.000000
# 2296  2296      0.000000
# 2297  2297      0.000000
# 2298  2298      0.000000
# 2299  2299      0.000000
#
# [2300 rows x 2 columns]

# %%
df2_y = df2.copy()
df2
df2_y = increaseonly(df2_y.loc[df2_y.Mass<140000])
#df2_y['Time'] *= 1/12.
df2_y['Mass'] = df2_y['Mass']/20000
ax = df2_y.plot('Time','Mass',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
import numpy as np
major_y_ticks = np.arange(0, 20, 1)

ax.set_yticks(major_y_ticks)
major_x_ticks = np.arange(0, 200*12, 5*12)
ax.set_xticks(major_x_ticks)

# And a corresponding grid
ax.grid(which='both')

plt.show()
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=696.0, right=696.0
#   'left=%s, right=%s') % (left, right))

# %%
df2_y_unit = pd.DataFrame()

df2_y_unit['Time'] = df2_y['Time']
df2_y_build_unit = pd.DataFrame()
df2_y_unit['Unit'] = df2_y['Mass']


df2_y_unit['Unit'] = df2_y_unit['Unit'].apply(lambda x: int(x) + 1 if x > int(x) else int(x))


df2_y_build_unit['Time'] = df2_y_unit['Time']
df2_y_build_unit['Build'] = (df2_y_unit['Unit'] - df2_y_unit['Unit'].shift(1))
df2_y_build_unit= df2_y_build_unit.dropna()

#df2_y_build_unit['Build'] = df2_y_build_unit['Build'].apply(lambda x: int(x) + 1 if x > int(x) else int(x))
df2_y_build_unit = df2_y_build_unit.loc[df2_y_build_unit.Build>0]
#df2_y_build_unit['Time'] *= 12.
print(df2_y_build_unit['Time'].values-12.*2)
print(df2_y_build_unit['Build'].values)

#### REMEMBER to add the first step !!
# Out:
# []
# []

# %%
df2_y_build_unit['Build'].sum()
# Out:
# 0

# %%
fac = ['str_pu']
nucs = ()
coms = ()


df3 = tm.inventories(ev, facilities=fac)
# Out:
# /Users/mouginot/.local/lib/python3.5/site-packages/cymetric/timeseries.py:133: UserWarning: no nuclide provided
#   warnings.warn(wng_msg, UserWarning)

# %%
df3_y_m = df3
df3_y_m['Quantity'] = df3
ax = df3_y_m.plot('Time','Quantity',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
#import numpy as np
#major_y_ticks = np.arange(0, 60, 1)

#ax.set_yticks(major_y_ticks)
#major_x_ticks = np.arange(0, 200, 5)
#ax.set_xticks(major_x_ticks)



# And a corresponding grid
ax.grid(which='both')

plt.show()

# %%
df3
# Out:
#       Time  Quantity
# 0        0       0.0
# 1        1       1.0
# 2        2       2.0
# 3        3       3.0
# 4        4       4.0
# 5        5       5.0
# 6        6       6.0
# 7        7       7.0
# 8        8       8.0
# 9        9       9.0
# 10      10      10.0
# 11      11      11.0
# 12      12      12.0
# 13      13      13.0
# 14      14      14.0
# 15      15      15.0
# 16      16      16.0
# 17      17      17.0
# 18      18      18.0
# 19      19      19.0
# 20      20      20.0
# 21      21      21.0
# 22      22      22.0
# 23      23      23.0
# 24      24      24.0
# 25      25      25.0
# 26      26      26.0
# 27      27      27.0
# 28      28      28.0
# 29      29      29.0
# ...    ...       ...
# 2270  2270    2270.0
# 2271  2271    2271.0
# 2272  2272    2272.0
# 2273  2273    2273.0
# 2274  2274    2274.0
# 2275  2275    2275.0
# 2276  2276    2276.0
# 2277  2277    2277.0
# 2278  2278    2278.0
# 2279  2279    2279.0
# 2280  2280    2280.0
# 2281  2281    2281.0
# 2282  2282    2282.0
# 2283  2283    2283.0
# 2284  2284    2284.0
# 2285  2285    2285.0
# 2286  2286    2286.0
# 2287  2287    2287.0
# 2288  2288    2288.0
# 2289  2289    2289.0
# 2290  2290    2290.0
# 2291  2291    2291.0
# 2292  2292    2292.0
# 2293  2293    2293.0
# 2294  2294    2294.0
# 2295  2295    2295.0
# 2296  2296    2296.0
# 2297  2297    2297.0
# 2298  2298    2298.0
# 2299  2299    2299.0
#
# [2300 rows x 2 columns]

# %%
rec = ()
send = ['fab_sfr']
nucs = ()
coms = ()


df2 = tm.transactions(ev, receivers=rec, senders=send, nucs=nucs, commodities=coms)
sfr_frac = cyh.TransFrac(ev=ev, rec=rec, send=send, nucs2=['PU238','PU239','PU240','PU241','PU242'],nucs1=['U235','U238'])

# %%
sfr_frac.max()
# Out:
# Time    2299.0000
# Mass       0.0302
# dtype: float64

# %%
fac = ['sfr_fab']
nucs = ()
coms = ()


df3 = tm.inventories(ev, facilities=fac)
# Out:
# /Users/mouginot/.local/lib/python3.5/site-packages/cymetric/timeseries.py:133: UserWarning: no nuclide provided
#   warnings.warn(wng_msg, UserWarning)
# /Users/mouginot/.local/lib/python3.5/site-packages/cymetric/tools.py:151: UserWarning: Empty  provided for AgentId key.
#   warnings.warn(wng_msg, UserWarning)

# %%
df3_y_m = df3
df3_y_m['Quantity'] = df3
ax = df3_y_m.plot('Time','Quantity',linestyle='', marker='+', markersize='20' ,figsize = (20,12))
# Major ticks every 20, minor ticks every 5
#import numpy as np
#major_y_ticks = np.arange(0, 60, 1)

#ax.set_yticks(major_y_ticks)
#major_x_ticks = np.arange(0, 200, 5)
#ax.set_xticks(major_x_ticks)



# And a corresponding grid
ax.grid(which='both')

plt.show()

# %%
dfp = tm.get_power(ev, facilities=["sfr_a","sfr_b"])
dfp.plot('Time','Value',figsize = (20,12))

# %%
dfp = tm.get_power(ev, facilities=["lwr_a","lwr_b"])
dfp.plot('Time','Value',figsize = (20,12))
